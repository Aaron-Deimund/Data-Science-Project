# %%
import requests
from bs4 import BeautifulSoup

# %%
help('modules')
# Out:
# Please wait a moment while I gather a list of all available modules...
#
# IPython             bs4                 matplotlib          ssl
# PIL                 builtins            matplotlib_inline   sspi
# __future__          bz2                 mimetypes           sspicon
# _abc                cProfile            mistune             stack_data
# _aix_support        calendar            mmap                stat
# _argon2_cffi_bindings certifi             mmapfile            statistics
# _ast                cffi                mmsystem            string
# _asyncio            cgi                 modulefinder        stringprep
# _bisect             cgitb               msilib              struct
# _blake2             chardet             msvcrt              subprocess
# _bootsubprocess     charset_normalizer  multiprocessing     sunau
# _bz2                chunk               nbclassic           symtable
# _cffi_backend       click               nbclient            sys
# ...
